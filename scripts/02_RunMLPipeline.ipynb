# %%
import yaml
import sys 
import os
import logging
import joblib
import pandas as pd

logging.basicConfig(format="%(asctime)s;%(levelname)s;%(message)s",level=logging.INFO)

sys.path.append(os.path.join(os.path.dirname(sys.path[0]),'modules'))

# Import custom modules
from binning import iv_varsel, woe_bins
from fit import model_config, mltrain_loop

# %%
# Load Config
c = yaml.load(open('msft.yaml','r'),Loader=yaml.FullLoader)

data = pd.read_parquet(c['data'])

# %%
#data = pd.read_parquet(c['dpath']+c['dvarsel'])

# %%
rerun_varsel = False
rerun_binning = False
refit_models = False

if os.path.isfile(c['dpath']+c['dvarsel']):
    logging.info('Variable Selection dataset already exists')
    if rerun_varsel:
        logging.info('Variable Selection redone')
        iv_varsel(
            data,
            c['bads'],
            c['target'],
            c['dpath'],
            c['dvarsel'],
        )
else:
    logging.info('Variable Selection dataset not found. Start Variable Selection')
    iv_varsel(
        data,
        c['bads'],
        c['target'],
        c['dpath'],
        c['dvarsel'],
    )
# Out:
# 2020-10-19 22:45:33,179;INFO;Variable Selection dataset already exists

# %%
if os.path.isfile(c['dpath']+c['dbins']):
    logging.info('Woe Binning dataset already exists')
    if rerun_binning:
        logging.info('Woe Binning redone')
        data = pd.read_parquet(c['dpath']+c['dvarsel'])
        woe_bins(
            data,
            c['target'],
            c['bads'],
            c['dpath'],
            c['dbins'],
            c['ppath'],
        )
else:
    logging.info('Woe Binning dataset not found. Start Woe Binning')
    data = pd.read_parquet(c['dpath']+c['dvarsel'])
    woe_bins(
        data,
        c['target'],
        c['bads'],
        c['dpath'],
        c['dbins'],
        c['ppath'],
    )
# Out:
# 2020-10-19 22:45:36,314;INFO;Woe Binning dataset already exists

# %%
# C
models = model_config(m_dict=c['models'])

data = pd.read_parquet(c['dpath']+c['dvarsel'])
bfile = c['dpath']+c['dbins']
bins = joblib.load(bfile)

print(len(models))

mltrain_loop(
    models,
    data,
    bins,
    c['target'],
    offset_lst=[0],
    begin_training  = pd.Timestamp(c['begin_training']),
    end_training    = pd.Timestamp(c['end_training']),
    begin_valid     = pd.Timestamp(c['begin_valid']),
    end_valid       = pd.Timestamp(c['end_valid']),
    begin_test      = pd.Timestamp(c['begin_test']),
    end_test        = pd.Timestamp(c['end_test']),
    refit_models=refit_models
    )
# Out:
# 2020-10-19 22:45:40,764;INFO;Fitting 38 models: ['LogisticRegression_l1_ratio0_penaltyl2_solversaga', 'SVC_C0.5_gammaauto_kernellinear_max_iter1000_probabilityTrue', 'SVC_C1_gammascale_kernelrbf_max_iter1000_probabilityTrue', 'MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(50, 50)_learning_rateconstant_max_iter1000_solveradam', 'DecisionTreeClassifier_criteriongini_max_depth8', 'MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(60, 40)_learning_rateconstant_max_iter1000_solveradam', 'SVC_C1_gammaauto_kernellinear_max_iter1000_probabilityTrue', 'RandomForestClassifier_max_depth2_n_estimators500', 'SVC_C0.5_gammascale_kernelsigmoid_max_iter1000_probabilityTrue', 'RandomForestClassifier_max_depth10_n_estimators500', 'SVC_C1_gammaauto_kernelrbf_max_iter1000_probabilityTrue', 'DecisionTreeClassifier_criteriongini_max_depth10', 'MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(70, 30)_learning_rateconstant_max_iter1000_solveradam', 'LogisticRegression_l1_ratio1_penaltyl1_solversaga', 'LogisticRegression_l1_ratio0.5_penaltyl1_solversaga', 'MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(90, 10)_learning_rateconstant_max_iter1000_solveradam', 'DecisionTreeClassifier_criteriongini_max_depth2', 'SVC_C0.5_gammaauto_kernelpoly_max_iter1000_probabilityTrue', 'LogisticRegression_l1_ratio0.5_penaltyelasticnet_solversaga', 'LogisticRegression_l1_ratio1_penaltyl2_solversaga', 'SVC_C0.5_gammascale_kernelrbf_max_iter1000_probabilityTrue', 'SVC_C0.5_gammaauto_kernelrbf_max_iter1000_probabilityTrue', 'DecisionTreeClassifier_criteriongini_max_depth6', 'RandomForestClassifier_max_depth8_n_estimators500', 'SVC_C0.5_gammascale_kernellinear_max_iter1000_probabilityTrue', 'RandomForestClassifier_max_depth6_n_estimators500', 'SVC_C1_gammascale_kernelsigmoid_max_iter1000_probabilityTrue', 'SVC_C1_gammascale_kernellinear_max_iter1000_probabilityTrue', 'LogisticRegression_l1_ratio0_penaltyelasticnet_solversaga', 'SVC_C0.5_gammaauto_kernelsigmoid_max_iter1000_probabilityTrue', 'LogisticRegression_l1_ratio0_penaltyl1_solversaga', 'LogisticRegression_l1_ratio0.5_penaltyl2_solversaga', 'SVC_C1_gammaauto_kernelpoly_max_iter1000_probabilityTrue', 'SVC_C0.5_gammascale_kernelpoly_max_iter1000_probabilityTrue', 'SVC_C1_gammaauto_kernelsigmoid_max_iter1000_probabilityTrue', 'SVC_C1_gammascale_kernelpoly_max_iter1000_probabilityTrue', 'MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(80, 20)_learning_rateconstant_max_iter1000_solveradam', 'LogisticRegression_l1_ratio1_penaltyelasticnet_solversaga']
# 38
# [INFO] converting into woe values ...
# [INFO] converting into woe values ...
# [INFO] converting into woe values ...
# 2020-10-19 22:45:41,626;INFO;Model LogisticRegression_l1_ratio0_penaltyl2_solversaga: Starting
# 2020-10-19 22:45:41,626;INFO;Model LogisticRegression_l1_ratio0_penaltyl2_solversaga: Fitting started
# 2020-10-19 22:45:41,646;INFO;Model LogisticRegression_l1_ratio0_penaltyl2_solversaga: Fitting ended
# 2020-10-19 22:45:41,674;INFO;Model LogisticRegression_l1_ratio0_penaltyl2_solversaga: Metrics Calculated
# 2020-10-19 22:45:41,676;INFO;Model LogisticRegression_l1_ratio0_penaltyl2_solversaga: Finished 1/38
# 2020-10-19 22:45:41,679;INFO;Model SVC_C0.5_gammaauto_kernellinear_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:45:41,681;INFO;Model SVC_C0.5_gammaauto_kernellinear_max_iter1000_probabilityTrue: Fitting started
# 2009-08-17 00:00:00 2017-12-29 00:00:00
# 2018-01-02 00:00:00 2018-12-31 00:00:00
# 2019-01-02 00:00:00 2019-08-16 00:00:00
# 2020-10-19 22:45:42,383;INFO;Model SVC_C0.5_gammaauto_kernellinear_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:45:42,667;INFO;Model SVC_C0.5_gammaauto_kernellinear_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:45:42,667;INFO;Model SVC_C0.5_gammaauto_kernellinear_max_iter1000_probabilityTrue: Finished 2/38
# 2020-10-19 22:45:42,668;INFO;Model SVC_C1_gammascale_kernelrbf_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:45:42,668;INFO;Model SVC_C1_gammascale_kernelrbf_max_iter1000_probabilityTrue: Fitting started
# 2020-10-19 22:45:43,864;INFO;Model SVC_C1_gammascale_kernelrbf_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:45:44,295;INFO;Model SVC_C1_gammascale_kernelrbf_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:45:44,295;INFO;Model SVC_C1_gammascale_kernelrbf_max_iter1000_probabilityTrue: Finished 3/38
# 2020-10-19 22:45:44,296;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(50, 50)_learning_rateconstant_max_iter1000_solveradam: Starting
# 2020-10-19 22:45:44,296;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(50, 50)_learning_rateconstant_max_iter1000_solveradam: Fitting started
# 2020-10-19 22:45:45,226;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(50, 50)_learning_rateconstant_max_iter1000_solveradam: Fitting ended
# 2020-10-19 22:45:45,294;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(50, 50)_learning_rateconstant_max_iter1000_solveradam: Metrics Calculated
# 2020-10-19 22:45:45,295;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(50, 50)_learning_rateconstant_max_iter1000_solveradam: Finished 4/38
# 2020-10-19 22:45:45,295;INFO;Model DecisionTreeClassifier_criteriongini_max_depth8: Starting
# 2020-10-19 22:45:45,296;INFO;Model DecisionTreeClassifier_criteriongini_max_depth8: Fitting started
# 2020-10-19 22:45:45,306;INFO;Model DecisionTreeClassifier_criteriongini_max_depth8: Fitting ended
# 2020-10-19 22:45:45,327;INFO;Model DecisionTreeClassifier_criteriongini_max_depth8: Metrics Calculated
# 2020-10-19 22:45:45,327;INFO;Model DecisionTreeClassifier_criteriongini_max_depth8: Finished 5/38
# 2020-10-19 22:45:45,328;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(60, 40)_learning_rateconstant_max_iter1000_solveradam: Starting
# 2020-10-19 22:45:45,328;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(60, 40)_learning_rateconstant_max_iter1000_solveradam: Fitting started
# 2020-10-19 22:45:46,425;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(60, 40)_learning_rateconstant_max_iter1000_solveradam: Fitting ended
# 2020-10-19 22:45:46,506;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(60, 40)_learning_rateconstant_max_iter1000_solveradam: Metrics Calculated
# 2020-10-19 22:45:46,507;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(60, 40)_learning_rateconstant_max_iter1000_solveradam: Finished 6/38
# 2020-10-19 22:45:46,507;INFO;Model SVC_C1_gammaauto_kernellinear_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:45:46,508;INFO;Model SVC_C1_gammaauto_kernellinear_max_iter1000_probabilityTrue: Fitting started
# 2020-10-19 22:45:47,245;INFO;Model SVC_C1_gammaauto_kernellinear_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:45:47,517;INFO;Model SVC_C1_gammaauto_kernellinear_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:45:47,517;INFO;Model SVC_C1_gammaauto_kernellinear_max_iter1000_probabilityTrue: Finished 7/38
# 2020-10-19 22:45:47,517;INFO;Model RandomForestClassifier_max_depth2_n_estimators500: Starting
# 2020-10-19 22:45:47,518;INFO;Model RandomForestClassifier_max_depth2_n_estimators500: Fitting started
# 2020-10-19 22:45:48,209;INFO;Model RandomForestClassifier_max_depth2_n_estimators500: Fitting ended
# 2020-10-19 22:45:48,545;INFO;Model RandomForestClassifier_max_depth2_n_estimators500: Metrics Calculated
# 2020-10-19 22:45:48,546;INFO;Model RandomForestClassifier_max_depth2_n_estimators500: Finished 8/38
# 2020-10-19 22:45:48,548;INFO;Model SVC_C0.5_gammascale_kernelsigmoid_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:45:48,548;INFO;Model SVC_C0.5_gammascale_kernelsigmoid_max_iter1000_probabilityTrue: Fitting started
# 2020-10-19 22:45:49,790;INFO;Model SVC_C0.5_gammascale_kernelsigmoid_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:45:50,258;INFO;Model SVC_C0.5_gammascale_kernelsigmoid_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:45:50,259;INFO;Model SVC_C0.5_gammascale_kernelsigmoid_max_iter1000_probabilityTrue: Finished 9/38
# 2020-10-19 22:45:50,259;INFO;Model RandomForestClassifier_max_depth10_n_estimators500: Starting
# 2020-10-19 22:45:50,260;INFO;Model RandomForestClassifier_max_depth10_n_estimators500: Fitting started
# 2020-10-19 22:45:51,356;INFO;Model RandomForestClassifier_max_depth10_n_estimators500: Fitting ended
# 2020-10-19 22:45:51,752;INFO;Model RandomForestClassifier_max_depth10_n_estimators500: Metrics Calculated
# 2020-10-19 22:45:51,752;INFO;Model RandomForestClassifier_max_depth10_n_estimators500: Finished 10/38
# 2020-10-19 22:45:51,753;INFO;Model SVC_C1_gammaauto_kernelrbf_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:45:51,754;INFO;Model SVC_C1_gammaauto_kernelrbf_max_iter1000_probabilityTrue: Fitting started
# 2020-10-19 22:45:52,997;INFO;Model SVC_C1_gammaauto_kernelrbf_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:45:53,451;INFO;Model SVC_C1_gammaauto_kernelrbf_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:45:53,451;INFO;Model SVC_C1_gammaauto_kernelrbf_max_iter1000_probabilityTrue: Finished 11/38
# 2020-10-19 22:45:53,452;INFO;Model DecisionTreeClassifier_criteriongini_max_depth10: Starting
# 2020-10-19 22:45:53,452;INFO;Model DecisionTreeClassifier_criteriongini_max_depth10: Fitting started
# 2020-10-19 22:45:53,464;INFO;Model DecisionTreeClassifier_criteriongini_max_depth10: Fitting ended
# 2020-10-19 22:45:53,483;INFO;Model DecisionTreeClassifier_criteriongini_max_depth10: Metrics Calculated
# 2020-10-19 22:45:53,484;INFO;Model DecisionTreeClassifier_criteriongini_max_depth10: Finished 12/38
# 2020-10-19 22:45:53,484;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(70, 30)_learning_rateconstant_max_iter1000_solveradam: Starting
# 2020-10-19 22:45:53,485;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(70, 30)_learning_rateconstant_max_iter1000_solveradam: Fitting started
# 2020-10-19 22:45:54,345;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(70, 30)_learning_rateconstant_max_iter1000_solveradam: Fitting ended
# 2020-10-19 22:45:54,387;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(70, 30)_learning_rateconstant_max_iter1000_solveradam: Metrics Calculated
# 2020-10-19 22:45:54,387;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(70, 30)_learning_rateconstant_max_iter1000_solveradam: Finished 13/38
# 2020-10-19 22:45:54,388;INFO;Model LogisticRegression_l1_ratio1_penaltyl1_solversaga: Starting
# 2020-10-19 22:45:54,388;INFO;Model LogisticRegression_l1_ratio1_penaltyl1_solversaga: Fitting started
# 2020-10-19 22:45:54,441;INFO;Model LogisticRegression_l1_ratio1_penaltyl1_solversaga: Fitting ended
# 2020-10-19 22:45:54,490;INFO;Model LogisticRegression_l1_ratio1_penaltyl1_solversaga: Metrics Calculated
# 2020-10-19 22:45:54,491;INFO;Model LogisticRegression_l1_ratio1_penaltyl1_solversaga: Finished 14/38
# 2020-10-19 22:45:54,491;INFO;Model LogisticRegression_l1_ratio0.5_penaltyl1_solversaga: Starting
# 2020-10-19 22:45:54,491;INFO;Model LogisticRegression_l1_ratio0.5_penaltyl1_solversaga: Fitting started
# 2020-10-19 22:45:54,546;INFO;Model LogisticRegression_l1_ratio0.5_penaltyl1_solversaga: Fitting ended
# 2020-10-19 22:45:54,567;INFO;Model LogisticRegression_l1_ratio0.5_penaltyl1_solversaga: Metrics Calculated
# 2020-10-19 22:45:54,567;INFO;Model LogisticRegression_l1_ratio0.5_penaltyl1_solversaga: Finished 15/38
# 2020-10-19 22:45:54,567;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(90, 10)_learning_rateconstant_max_iter1000_solveradam: Starting
# 2020-10-19 22:45:54,569;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(90, 10)_learning_rateconstant_max_iter1000_solveradam: Fitting started
# 2020-10-19 22:45:55,933;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(90, 10)_learning_rateconstant_max_iter1000_solveradam: Fitting ended
# 2020-10-19 22:45:55,984;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(90, 10)_learning_rateconstant_max_iter1000_solveradam: Metrics Calculated
# 2020-10-19 22:45:55,988;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(90, 10)_learning_rateconstant_max_iter1000_solveradam: Finished 16/38
# 2020-10-19 22:45:55,989;INFO;Model DecisionTreeClassifier_criteriongini_max_depth2: Starting
# 2020-10-19 22:45:55,996;INFO;Model DecisionTreeClassifier_criteriongini_max_depth2: Fitting started
# 2020-10-19 22:45:56,010;INFO;Model DecisionTreeClassifier_criteriongini_max_depth2: Fitting ended
# 2020-10-19 22:45:56,052;INFO;Model DecisionTreeClassifier_criteriongini_max_depth2: Metrics Calculated
# 2020-10-19 22:45:56,054;INFO;Model DecisionTreeClassifier_criteriongini_max_depth2: Finished 17/38
# 2020-10-19 22:45:56,055;INFO;Model SVC_C0.5_gammaauto_kernelpoly_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:45:56,055;INFO;Model SVC_C0.5_gammaauto_kernelpoly_max_iter1000_probabilityTrue: Fitting started
# 2020-10-19 22:45:56,882;INFO;Model SVC_C0.5_gammaauto_kernelpoly_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:45:57,190;INFO;Model SVC_C0.5_gammaauto_kernelpoly_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:45:57,191;INFO;Model SVC_C0.5_gammaauto_kernelpoly_max_iter1000_probabilityTrue: Finished 18/38
# 2020-10-19 22:45:57,192;INFO;Model LogisticRegression_l1_ratio0.5_penaltyelasticnet_solversaga: Starting
# 2020-10-19 22:45:57,192;INFO;Model LogisticRegression_l1_ratio0.5_penaltyelasticnet_solversaga: Fitting started
# 2020-10-19 22:45:57,213;INFO;Model LogisticRegression_l1_ratio0.5_penaltyelasticnet_solversaga: Fitting ended
# 2020-10-19 22:45:57,239;INFO;Model LogisticRegression_l1_ratio0.5_penaltyelasticnet_solversaga: Metrics Calculated
# 2020-10-19 22:45:57,241;INFO;Model LogisticRegression_l1_ratio0.5_penaltyelasticnet_solversaga: Finished 19/38
# 2020-10-19 22:45:57,249;INFO;Model LogisticRegression_l1_ratio1_penaltyl2_solversaga: Starting
# 2020-10-19 22:45:57,250;INFO;Model LogisticRegression_l1_ratio1_penaltyl2_solversaga: Fitting started
# 2020-10-19 22:45:57,286;INFO;Model LogisticRegression_l1_ratio1_penaltyl2_solversaga: Fitting ended
# 2020-10-19 22:45:57,343;INFO;Model LogisticRegression_l1_ratio1_penaltyl2_solversaga: Metrics Calculated
# 2020-10-19 22:45:57,344;INFO;Model LogisticRegression_l1_ratio1_penaltyl2_solversaga: Finished 20/38
# 2020-10-19 22:45:57,345;INFO;Model SVC_C0.5_gammascale_kernelrbf_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:45:57,350;INFO;Model SVC_C0.5_gammascale_kernelrbf_max_iter1000_probabilityTrue: Fitting started
# 2020-10-19 22:45:58,586;INFO;Model SVC_C0.5_gammascale_kernelrbf_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:45:59,023;INFO;Model SVC_C0.5_gammascale_kernelrbf_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:45:59,023;INFO;Model SVC_C0.5_gammascale_kernelrbf_max_iter1000_probabilityTrue: Finished 21/38
# 2020-10-19 22:45:59,024;INFO;Model SVC_C0.5_gammaauto_kernelrbf_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:45:59,024;INFO;Model SVC_C0.5_gammaauto_kernelrbf_max_iter1000_probabilityTrue: Fitting started
# 2020-10-19 22:46:00,278;INFO;Model SVC_C0.5_gammaauto_kernelrbf_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:46:00,745;INFO;Model SVC_C0.5_gammaauto_kernelrbf_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:46:00,745;INFO;Model SVC_C0.5_gammaauto_kernelrbf_max_iter1000_probabilityTrue: Finished 22/38
# 2020-10-19 22:46:00,746;INFO;Model DecisionTreeClassifier_criteriongini_max_depth6: Starting
# 2020-10-19 22:46:00,746;INFO;Model DecisionTreeClassifier_criteriongini_max_depth6: Fitting started
# 2020-10-19 22:46:00,755;INFO;Model DecisionTreeClassifier_criteriongini_max_depth6: Fitting ended
# 2020-10-19 22:46:00,774;INFO;Model DecisionTreeClassifier_criteriongini_max_depth6: Metrics Calculated
# 2020-10-19 22:46:00,774;INFO;Model DecisionTreeClassifier_criteriongini_max_depth6: Finished 23/38
# 2020-10-19 22:46:00,775;INFO;Model RandomForestClassifier_max_depth8_n_estimators500: Starting
# 2020-10-19 22:46:00,775;INFO;Model RandomForestClassifier_max_depth8_n_estimators500: Fitting started
# 2020-10-19 22:46:01,792;INFO;Model RandomForestClassifier_max_depth8_n_estimators500: Fitting ended
# 2020-10-19 22:46:02,209;INFO;Model RandomForestClassifier_max_depth8_n_estimators500: Metrics Calculated
# 2020-10-19 22:46:02,209;INFO;Model RandomForestClassifier_max_depth8_n_estimators500: Finished 24/38
# 2020-10-19 22:46:02,210;INFO;Model SVC_C0.5_gammascale_kernellinear_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:46:02,210;INFO;Model SVC_C0.5_gammascale_kernellinear_max_iter1000_probabilityTrue: Fitting started
# 2020-10-19 22:46:02,911;INFO;Model SVC_C0.5_gammascale_kernellinear_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:46:03,189;INFO;Model SVC_C0.5_gammascale_kernellinear_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:46:03,190;INFO;Model SVC_C0.5_gammascale_kernellinear_max_iter1000_probabilityTrue: Finished 25/38
# 2020-10-19 22:46:03,190;INFO;Model RandomForestClassifier_max_depth6_n_estimators500: Starting
# 2020-10-19 22:46:03,191;INFO;Model RandomForestClassifier_max_depth6_n_estimators500: Fitting started
# 2020-10-19 22:46:04,098;INFO;Model RandomForestClassifier_max_depth6_n_estimators500: Fitting ended
# 2020-10-19 22:46:04,432;INFO;Model RandomForestClassifier_max_depth6_n_estimators500: Metrics Calculated
# 2020-10-19 22:46:04,433;INFO;Model RandomForestClassifier_max_depth6_n_estimators500: Finished 26/38
# 2020-10-19 22:46:04,433;INFO;Model SVC_C1_gammascale_kernelsigmoid_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:46:04,434;INFO;Model SVC_C1_gammascale_kernelsigmoid_max_iter1000_probabilityTrue: Fitting started
# 2020-10-19 22:46:05,515;INFO;Model SVC_C1_gammascale_kernelsigmoid_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:46:05,872;INFO;Model SVC_C1_gammascale_kernelsigmoid_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:46:05,874;INFO;Model SVC_C1_gammascale_kernelsigmoid_max_iter1000_probabilityTrue: Finished 27/38
# 2020-10-19 22:46:05,874;INFO;Model SVC_C1_gammascale_kernellinear_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:46:05,874;INFO;Model SVC_C1_gammascale_kernellinear_max_iter1000_probabilityTrue: Fitting started
# 2020-10-19 22:46:06,565;INFO;Model SVC_C1_gammascale_kernellinear_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:46:06,841;INFO;Model SVC_C1_gammascale_kernellinear_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:46:06,841;INFO;Model SVC_C1_gammascale_kernellinear_max_iter1000_probabilityTrue: Finished 28/38
# 2020-10-19 22:46:06,841;INFO;Model LogisticRegression_l1_ratio0_penaltyelasticnet_solversaga: Starting
# 2020-10-19 22:46:06,842;INFO;Model LogisticRegression_l1_ratio0_penaltyelasticnet_solversaga: Fitting started
# 2020-10-19 22:46:06,859;INFO;Model LogisticRegression_l1_ratio0_penaltyelasticnet_solversaga: Fitting ended
# 2020-10-19 22:46:06,881;INFO;Model LogisticRegression_l1_ratio0_penaltyelasticnet_solversaga: Metrics Calculated
# 2020-10-19 22:46:06,883;INFO;Model LogisticRegression_l1_ratio0_penaltyelasticnet_solversaga: Finished 29/38
# 2020-10-19 22:46:06,885;INFO;Model SVC_C0.5_gammaauto_kernelsigmoid_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:46:06,886;INFO;Model SVC_C0.5_gammaauto_kernelsigmoid_max_iter1000_probabilityTrue: Fitting started
# 2020-10-19 22:46:08,122;INFO;Model SVC_C0.5_gammaauto_kernelsigmoid_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:46:08,586;INFO;Model SVC_C0.5_gammaauto_kernelsigmoid_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:46:08,587;INFO;Model SVC_C0.5_gammaauto_kernelsigmoid_max_iter1000_probabilityTrue: Finished 30/38
# 2020-10-19 22:46:08,587;INFO;Model LogisticRegression_l1_ratio0_penaltyl1_solversaga: Starting
# 2020-10-19 22:46:08,588;INFO;Model LogisticRegression_l1_ratio0_penaltyl1_solversaga: Fitting started
# 2020-10-19 22:46:08,614;INFO;Model LogisticRegression_l1_ratio0_penaltyl1_solversaga: Fitting ended
# 2020-10-19 22:46:08,644;INFO;Model LogisticRegression_l1_ratio0_penaltyl1_solversaga: Metrics Calculated
# 2020-10-19 22:46:08,644;INFO;Model LogisticRegression_l1_ratio0_penaltyl1_solversaga: Finished 31/38
# 2020-10-19 22:46:08,645;INFO;Model LogisticRegression_l1_ratio0.5_penaltyl2_solversaga: Starting
# 2020-10-19 22:46:08,645;INFO;Model LogisticRegression_l1_ratio0.5_penaltyl2_solversaga: Fitting started
# 2020-10-19 22:46:08,674;INFO;Model LogisticRegression_l1_ratio0.5_penaltyl2_solversaga: Fitting ended
# 2020-10-19 22:46:08,702;INFO;Model LogisticRegression_l1_ratio0.5_penaltyl2_solversaga: Metrics Calculated
# 2020-10-19 22:46:08,705;INFO;Model LogisticRegression_l1_ratio0.5_penaltyl2_solversaga: Finished 32/38
# 2020-10-19 22:46:08,706;INFO;Model SVC_C1_gammaauto_kernelpoly_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:46:08,709;INFO;Model SVC_C1_gammaauto_kernelpoly_max_iter1000_probabilityTrue: Fitting started
# 2020-10-19 22:46:09,543;INFO;Model SVC_C1_gammaauto_kernelpoly_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:46:09,839;INFO;Model SVC_C1_gammaauto_kernelpoly_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:46:09,840;INFO;Model SVC_C1_gammaauto_kernelpoly_max_iter1000_probabilityTrue: Finished 33/38
# 2020-10-19 22:46:09,840;INFO;Model SVC_C0.5_gammascale_kernelpoly_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:46:09,840;INFO;Model SVC_C0.5_gammascale_kernelpoly_max_iter1000_probabilityTrue: Fitting started
# 2020-10-19 22:46:10,630;INFO;Model SVC_C0.5_gammascale_kernelpoly_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:46:10,908;INFO;Model SVC_C0.5_gammascale_kernelpoly_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:46:10,908;INFO;Model SVC_C0.5_gammascale_kernelpoly_max_iter1000_probabilityTrue: Finished 34/38
# 2020-10-19 22:46:10,909;INFO;Model SVC_C1_gammaauto_kernelsigmoid_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:46:10,909;INFO;Model SVC_C1_gammaauto_kernelsigmoid_max_iter1000_probabilityTrue: Fitting started
# 2020-10-19 22:46:12,143;INFO;Model SVC_C1_gammaauto_kernelsigmoid_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:46:12,597;INFO;Model SVC_C1_gammaauto_kernelsigmoid_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:46:12,598;INFO;Model SVC_C1_gammaauto_kernelsigmoid_max_iter1000_probabilityTrue: Finished 35/38
# 2020-10-19 22:46:12,598;INFO;Model SVC_C1_gammascale_kernelpoly_max_iter1000_probabilityTrue: Starting
# 2020-10-19 22:46:12,599;INFO;Model SVC_C1_gammascale_kernelpoly_max_iter1000_probabilityTrue: Fitting started
# 2020-10-19 22:46:13,365;INFO;Model SVC_C1_gammascale_kernelpoly_max_iter1000_probabilityTrue: Fitting ended
# 2020-10-19 22:46:13,624;INFO;Model SVC_C1_gammascale_kernelpoly_max_iter1000_probabilityTrue: Metrics Calculated
# 2020-10-19 22:46:13,625;INFO;Model SVC_C1_gammascale_kernelpoly_max_iter1000_probabilityTrue: Finished 36/38
# 2020-10-19 22:46:13,626;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(80, 20)_learning_rateconstant_max_iter1000_solveradam: Starting
# 2020-10-19 22:46:13,626;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(80, 20)_learning_rateconstant_max_iter1000_solveradam: Fitting started
# 2020-10-19 22:46:14,457;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(80, 20)_learning_rateconstant_max_iter1000_solveradam: Fitting ended
# 2020-10-19 22:46:14,495;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(80, 20)_learning_rateconstant_max_iter1000_solveradam: Metrics Calculated
# 2020-10-19 22:46:14,495;INFO;Model MLPClassifier_activationlogistic_alpha0.0001_hidden_layer_sizes(80, 20)_learning_rateconstant_max_iter1000_solveradam: Finished 37/38
# 2020-10-19 22:46:14,496;INFO;Model LogisticRegression_l1_ratio1_penaltyelasticnet_solversaga: Starting
# 2020-10-19 22:46:14,496;INFO;Model LogisticRegression_l1_ratio1_penaltyelasticnet_solversaga: Fitting started
# 2020-10-19 22:46:14,520;INFO;Model LogisticRegression_l1_ratio1_penaltyelasticnet_solversaga: Fitting ended
# 2020-10-19 22:46:14,546;INFO;Model LogisticRegression_l1_ratio1_penaltyelasticnet_solversaga: Metrics Calculated
# 2020-10-19 22:46:14,547;INFO;Model LogisticRegression_l1_ratio1_penaltyelasticnet_solversaga: Finished 38/38
